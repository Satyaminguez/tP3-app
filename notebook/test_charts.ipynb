# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

from utils.data import load_data
from utils.charts import *

df = load_data("../data/processed/adresses_geocodees_20251216_163809.parquet")
df.head()
# Out:
#                     adresse_origine  \
# 0          20 avenue de Ségur Paris
# 1                 Tour Eiffel Paris
# 2              Place Bellecour Lyon
# 3              Vieux Port Marseille
# 4  Cathédrale Notre-Dame Strasbourg
#
#                                             label   latitude  longitude  \
# 0                  20 Avenue de Ségur 75007 Paris  48.850699   2.308628
# 1               Avenue Gustave Eiffel 75007 Paris  48.857739   2.294844
# 2                      Place Bellecour 69002 Lyon  45.756681   4.831715
# 3  Voie d'accès tunnel vieux port 13007 Marseille  43.292041   5.363544
# 4         Place de la Cathédrale 67000 Strasbourg  48.581918   7.750252
#
#       score code_postal code_insee     qualite
# 0  0.971645       75007      75107  excellente
# 1  0.377595       75007      75107      faible
# 2  0.967352       69002      69382  excellente
# 3  0.682063       13007      13207       bonne
# 4  0.537468       67000      67482       bonne

# %%
# Adapter les colonnes à votre dataset
import nbformat
fig = create_bar_chart(
    df=df,
    x="score",
    y="label",
    title="score par adresse",
)
fig.show()
